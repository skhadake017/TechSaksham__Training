# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\shrut\Downloads\archive (3)\synthetic_beverage_sales_data.csv")
df.head()
# Out:
#   Order_ID Customer_ID Customer_Type             Product     Category  \
# 0     ORD1     CUS1496           B2B          Vio Wasser        Water
# 1     ORD1     CUS1496           B2B               Evian        Water
# 2     ORD1     CUS1496           B2B              Sprite  Soft Drinks
# 3     ORD1     CUS1496           B2B  Rauch Multivitamin       Juices
# 4     ORD1     CUS1496           B2B        Gerolsteiner        Water
#
#    Unit_Price  Quantity  Discount  Total_Price             Region  Order_Date
# 0        1.66      53.0      0.10        79.18  Baden-Württemberg  2023-08-23
# 1        1.56      90.0      0.10       126.36  Baden-Württemberg  2023-08-23
# 2        1.17      73.0      0.05        81.14  Baden-Württemberg  2023-08-23
# 3        3.22      59.0      0.10       170.98  Baden-Württemberg  2023-08-23
# 4        0.87      35.0      0.10        27.40  Baden-Württemberg  2023-08-23

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Type', 'Product', 'Category',
#        'Unit_Price', 'Quantity', 'Discount', 'Total_Price', 'Region',
#        'Order_Date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580643 entries, 0 to 2580642
# Data columns (total 11 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Order_ID       object
#  1   Customer_ID    object
#  2   Customer_Type  object
#  3   Product        object
#  4   Category       object
#  5   Unit_Price     float64
#  6   Quantity       float64
#  7   Discount       float64
#  8   Total_Price    float64
#  9   Region         object
#  10  Order_Date     object
# dtypes: float64(4), object(7)
# memory usage: 216.6+ MB

# %%
df.describe()
# Out:
#          Unit_Price      Quantity      Discount   Total_Price
# count  2.580642e+06  2.580642e+06  2.580642e+06  2.580642e+06
# mean   5.823332e+00  2.315532e+01  2.975008e-02  1.306477e+02
# std    1.471978e+01  2.690697e+01  4.480508e-02  5.095052e+02
# min    3.200000e-01  1.000000e+00  0.000000e+00  3.000000e-01
# 25%    1.050000e+00  6.000000e+00  0.000000e+00  8.400000e+00
# 50%    1.750000e+00  1.100000e+01  0.000000e+00  2.114000e+01
# 75%    3.210000e+00  3.000000e+01  5.000000e-02  6.955000e+01
# max    1.681800e+02  1.000000e+02  1.500000e-01  1.429530e+04

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Product'],df['Total_Price'])
plt.xlabel("Product")
plt.ylabel("Total_Price")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(10,5))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Type', 'Product', 'Category',
#        'Unit_Price', 'Quantity', 'Discount', 'Total_Price', 'Region',
#        'Order_Date'],
#       dtype='object')

# %%
columns_plot=['Customer_ID','Customer_Type','Product','Category','Unit_Price','Quantity']
for i in columns_plot:
    bar_plot(i)
# Out:
# Customer_ID:
# Customer_ID
# CUS2800    599
# CUS2791    591
# CUS7157    582
# CUS6170    581
# CUS8939    581
#           ...
# CUS2444    319
# CUS6854    317
# CUS6312    315
# CUS7614    314
# CUS7469    312
# Name: count, Length: 10000, dtype: int64
# Customer_Type:
# Customer_Type
# B2C    2872411
# B2B    1587863
# Name: count, dtype: int64
# Product:
# Product
# Hohes C Orange         167092
# Granini Apple          158272
# Rauch Multivitamin     158053
# Mango Juice            157876
# Tomato Juice           157656
# Cranberry Juice        157637
# Passion Fruit Juice    157182
# San Pellegrino         127311
# Vittel                 126643
# Volvic Touch           123502
# Evian                  123491
# Apollinaris            123121
# Volvic                 123046
# Vio Wasser             122814
# Selters                122716
# Gerolsteiner           122518
# Fritz-Kola             109614
# Sprite                  98680
# Coca-Cola               98020
# ...

# %%
plt.hist(df['Category'])
plt.show()

# %%
def hist_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(10,5))
    plt.hist(var,bins=10,edgecolor='black',alpha=0.7)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Type', 'Product', 'Category',
#        'Unit_Price', 'Quantity', 'Discount', 'Total_Price', 'Region',
#        'Order_Date'],
#       dtype='object')

# %%
columns_plot=['Customer_ID','Customer_Type','Product','Category','Unit_Price','Quantity']
for i in columns_plot:
    hist_plot(i)
# Out:
# Customer_ID:
# Customer_ID
# CUS2800    599
# CUS2791    591
# CUS7157    582
# CUS6170    581
# CUS8939    581
#           ...
# CUS2444    319
# CUS6854    317
# CUS6312    315
# CUS7614    314
# CUS7469    312
# Name: count, Length: 10000, dtype: int64
# Customer_Type:
# Customer_Type
# B2C    2872411
# B2B    1587863
# Name: count, dtype: int64
# Product:
# Product
# Hohes C Orange         167092
# Granini Apple          158272
# Rauch Multivitamin     158053
# Mango Juice            157876
# Tomato Juice           157656
# Cranberry Juice        157637
# Passion Fruit Juice    157182
# San Pellegrino         127311
# Vittel                 126643
# Volvic Touch           123502
# Evian                  123491
# Apollinaris            123121
# Volvic                 123046
# Vio Wasser             122814
# Selters                122716
# Gerolsteiner           122518
# Fritz-Kola             109614
# Sprite                  98680
# Coca-Cola               98020
# ...

# %%
df[['Unit_Price','Total_Price']].groupby('Unit_Price',as_index=False).mean().sort_values(by='Total_Price', ascending=False)
# Out:
#        Unit_Price   Total_Price
# 11906      168.18  14295.300000
# 11899      159.33  13335.920000
# 11897      157.95  13291.490000
# 11894      155.71  13235.350000
# 11883      151.68  13105.150000
# ...           ...           ...
# 24           0.56      5.806558
# 23           0.55      5.412526
# 15           0.47      5.043661
# 14           0.46      5.004043
# 17           0.49      5.003152
#
# [11907 rows x 2 columns]

# %%
sns.boxplot(df['Product'])
# Out:
# <Axes: ylabel='Product'>

# %%
df['Discount']=df['Discount'].fillna(df['Discount'].median())

# %%
df['Quantity']=df['Quantity'].fillna(df['Quantity'].median())

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Customer_Type    0
# Product          0
# Category         0
# Unit_Price       0
# Quantity         0
# Discount         0
# Total_Price      0
# Region           0
# Order_Date       1
# dtype: int64

# %%
df['Order_Date'].mode()
# Out:
# 0    2022-02-05
# Name: Order_Date, dtype: object

# %%
df['Order_Date']=df['Order_Date'].fillna(df['Order_Date'].mode()[0])

# %%
df.isna().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Customer_Type    0
# Product          0
# Category         0
# Unit_Price       0
# Quantity         0
# Discount         0
# Total_Price      0
# Region           0
# Order_Date       0
# dtype: int64

# %%
df.drop(labels=['Order_ID', 'Customer_ID', 'Customer_Type', 'Product', 'Category','Unit_Price', 'Quantity', 'Discount',],axis=1,inplace=True)

# %%
df.drop
# Out:
# <bound method DataFrame.drop of          Total_Price             Region  Order_Date
# 0              79.18  Baden-Württemberg  2023-08-23
# 1             126.36  Baden-Württemberg  2023-08-23
# 2              81.14  Baden-Württemberg  2023-08-23
# 3             170.98  Baden-Württemberg  2023-08-23
# 4              27.40  Baden-Württemberg  2023-08-23
# ...              ...                ...         ...
# 4460269        91.31        Brandenburg  2021-08-04
# 4460270        69.08        Brandenburg  2021-08-04
# 4460271        82.82        Brandenburg  2021-08-04
# 4460272        79.32        Brandenburg  2021-08-04
# 4460273       795.57        Brandenburg  2022-02-05
#
# [4460274 rows x 3 columns]>

# %%
x=np.array(['Category','Unit_Price','Quantity','Discount','Total_Price','Region'])
y=np.array([3,2,5,3,4,2])
plt.pie(y,labels=x)
plt.show()
